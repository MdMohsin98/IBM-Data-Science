# %% [markdown]
# # Description
# This notebook analyzez and visualizez the weather_data

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_9e91a732284843bd89ededd775e1673c = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='cuyQ0Vmrx1lmnfB12kywmjSSuxHquCaaLgv-XKEb6M2j',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.ap.cloud-object-storage.appdomain.cloud')

body = client_9e91a732284843bd89ededd775e1673c.get_object(Bucket='myproject-donotdelete-pr-h8j4xec4jy4u3f',Key='weather_data.xlsx')['Body']

df_data_0 = pd.read_excel(body.read())
df_data_0.head()
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
df_data_0
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
df_data_0.corr()
# Out:
#              temperature  windspeed
# temperature      1.00000    0.96862
# windspeed        0.96862    1.00000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.heatmap(df_data_0.corr())
# Out:
# <AxesSubplot:>

# %%
plt.plot(df_data_0['temperature'], df_data_0['windspeed'])
plt.xlabel("Temperature")
plt.ylabel("Windspeed")
# Out:
# Text(0, 0.5, 'Windspeed')
